# %% [markdown]
# <a href="https://colab.research.google.com/github/OllTuMucT/Neural-network/blob/main/Neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#импортируем модули и библиотеки
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
# %matplotlib inline
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import utils

# %%
# делим наш датасет на обучающую и тестовую выборку
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt','Sneaker', 'Bag', 'Ankleboot']

# %%
#Предварительная обработка данных

# %%
plt.figure()
plt.imshow(x_train[4000])
plt.colorbar()
plt.grid(False)

# %%
# нормализация данных
x_train = x_train / 255
x_test =  x_test / 255

# %%
plt.figure()
plt.imshow(x_train[4000])
plt.colorbar()
plt.grid(False)

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(x_train[i])
  plt.xlabel(class_names[y_train[i]])

# %%
# Создание модели нейронной сети
model =  keras.Sequential([
                           keras.layers.Flatten(input_shape=(28, 28)),
                           keras.layers.Dense(128, activation="relu"),
                           keras.layers.Dense(10, activation="softmax")
])

# %%
# Компиляция модели
model.compile(optimizer=tf.keras.optimizers.SGD(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Обучение модели
model.fit(x_train, y_train, epochs=25)
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0077 - accuracy: 0.9999
# Epoch 2/25
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0075 - accuracy: 0.9999
# Epoch 3/25
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9999
# Epoch 4/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0076 - accuracy: 0.9999
# Epoch 5/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0075 - accuracy: 0.9999
# Epoch 6/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 7/25
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9999
# Epoch 8/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0074 - accuracy: 0.9999
# Epoch 9/25
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0074 - accuracy: 0.9998
# Epoch 10/25
# ...

# %%
test_loss, text_acc =  model.evaluate(x_test, y_test)
print('Test accuracy:', text_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.6513 - accuracy: 0.8867
# Test accuracy: 0.8866999745368958

# %%
predictions = model.predict(x_train)

# %%
n = 300
plt.figure()
plt.imshow(x_train[n])
plt.colorbar()
plt.grid(False)
class_names[np.argmax(predictions[n])]
# Out:
# 'Sandal'
